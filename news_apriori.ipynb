# %%
import pandas as pd
from sklearn import preprocessing 
import math

# %% [markdown]
# ## Data extraction from Youtube dataset and user shopping basket list

# %%
dataset = pd.read_csv('/content/Market_Basket_Optimisation.csv', header = None)
transactions = []
for i in range(0, 7501):
  transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %%
transactions

# %%
elements = []
fooditems = []
for i in range(0,7501):
  for j in range(0,20):
    if transactions[i][j]!='nan':
      elements.append(transactions[i][j])
      
lst = list(dict.fromkeys(elements))
for i in range(0,len(lst)):
  item = list([lst[i],0,0,''])
  fooditems.append(item)

for i in range(0,7501):
  for j in range(0,20):
    if transactions[i][j]!='nan':
      for k in range(0,len(fooditems)):
        if transactions[i][j]==fooditems[k][0]:
          fooditems[k][1] = fooditems[k][1]+1

# %%
fooditems

# %%
def Sort(Data,l):
  for i in range(0, l):
    for j in range(0, l-1):
      if Data[j][1] <  Data[j + 1][1]:
        tempo = Data[j]
        Data[j]= Data[j + 1]
        Data[j + 1]= tempo

def Sort2(Data,l):
  for i in range(0, l):
    for j in range(0, l-1):
      if Data[j][3] <  Data[j + 1][3]:
        tempo = Data[j]
        Data[j]= Data[j + 1]
        Data[j + 1]= tempo

# %%
Sort(fooditems,len(fooditems))

# %%
import json
categories_data = []
dictdata = dict()

# %%
Flag = []
flag = dict()
count=0
news_categories = ['/content/IN_category_id.json','/content/CA_category_id.json','/content/DE_category_id.json','/content/FR_category_id.json',
                   '/content/GB_category_id.json','/content/JP_category_id.json','/content/KR_category_id.json',
                   '/content/MX_category_id.json','/content/RU_category_id.json','/content/US_category_id.json',]
for j in range(0,len(news_categories)):
  with open(news_categories[j]) as utubejson:
    jsondata = json.load(utubejson)
    for i in jsondata['items']:
      flag = {
          i['id']:{
              'categ':i['snippet']['title'],
          }
      }
      dictdata.update(flag)
      Flag=[i['snippet']['title'],i['id']]
      categories_data.append(Flag)
      Flag.clear

# %%
nsc = []
nsctg = []
for i in dictdata:
  nsctg= list([i, dictdata[i]['categ'],0,0,0])
  nsc.append(nsctg)

# %%
import csv

# %%
utubedata = []
file = ['/content/JP.csv','/content/RUSSIA.csv','/content/MEXICO.csv','/content/KR.csv',
        '/content/US.csv','/content/INDIA.csv','/content/DE.csv','/content/FR.csv','/content/GB.csv']
for i in file:
  with open(i) as data:
    utube = csv.reader(data)
    for row in utube:
      likes = list([row[0],row[1],row[2],row[3],])
      utubedata.append(likes)
    data.close

# %%
for i in range(0,len(utubedata)):
  for j in range(0,len(nsc)):
    if nsc[j][0]==utubedata[i][0]:
      nsc[j][2]= nsc[j][3]+int(utubedata[i][1])
      nsc[j][3]= nsc[j][3]+int(utubedata[i][2])
      nsc[j][4]= nsc[j][4]+int(utubedata[i][3])

# %%
fooditems

# %%
for i in range(0,len(fooditems)):
  if i < len(nsc):
    fooditems[i][2] = int(nsc[i][0])
    fooditems[i][3] = str(nsc[i][1])
  else:
    fooditems[i][2] = 0
    fooditems[i][3] = 'nan'
fooditems

# %%
feild = 'empty'
for i in range(0,7501):
  for j in range(0,20):
    if  transactions[i][j]!='nan':
      for k in range(0,len(fooditems)):
        if transactions[i][j]==fooditems[k][0]:
          field = fooditems[k][3]
      if field == 'empty':
        transactions[i][j]=''
      else:
        transactions[i][j] = field

# %%
transactions

# %%
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in /usr/local/lib/python3.6/dist-packages (1.1.2)

# %%
dataset1 = pd.read_csv('/content/Market_Basket_Optimisation.csv', header = None)
transactions1 = []
for i in range(0, 7501):
  transactions1.append([str(dataset1.values[i,j]) for j in range(0, 20)])

# %%
dataset2 = pd.read_csv('/content/dataset.csv', header = None)
transactions2 = []
for i in range(0, 7501):
  transactions2.append([str(dataset2.values[i,j]) for j in range(0, 20)])

# %%
from apyori import apriori
rules = apriori(transactions = transactions2, min_support = 0.003, min_confidence = 0.3, min_lift = 3, min_length = 2, max_length = 3)

# %%
results = list(rules)
print(results)
# Out:
# [RelationRecord(items=frozenset({'Gaming', 'Horror'}), support=0.015997866951073192, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Horror'}), items_add=frozenset({'Gaming'}), confidence=0.3234501347708895, lift=3.2919938411349285)]), RelationRecord(items=frozenset({'Comedy', 'Travel & Events', 'Anime/Animation'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Comedy', 'Anime/Animation'}), items_add=frozenset({'Travel & Events'}), confidence=0.41666666666666663, lift=3.215449245541838)]), RelationRecord(items=frozenset({'Travel & Events', 'Foreign', 'Anime/Animation'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Foreign', 'Anime/Animation'}), items_add=frozenset({'Travel & Events'}), confidence=0.4029850746268656, lift=3.1098673300165833)]), RelationRecord(items=frozenset({'Music', 'Movies', 'Anime/Animation'}), support=0.004399413411545127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Movies', 'Anime/Animation'}), items_add=frozenset({'Music'}), confidence=0.6111111111111112, lift=3.5099115194827295)]), RelationRecord(items=frozenset({'Travel & Events', 'Science & Technology', 'Anime/Animation'}), support=0.003199573390214638, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Science & Technology', 'Anime/Animation'}), items_add=frozenset({'Travel & Events'}), confidence=0.3934426229508197, lift=3.0362274843149164)]), RelationRecord(items=frozenset({'Travel & Events', 'Videoblogging', 'Anime/Animation'}), support=0.004799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Videoblogging', 'Anime/Animation'}), items_add=frozenset({'Travel & Events'}), confidence=0.4235294117647058, lift=3.2684095860566447)]), RelationRecord(items=frozenset({'Gaming', 'Autos & Vehicles', 'Horror'}), support=0.0041327822956939075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Autos & Vehicles', 'Horror'}), items_add=frozenset({'Gaming'}), confidence=0.3297872340425532, lift=3.3564912381997174)]), RelationRecord(items=frozenset({'Comedy', 'Classics', 'Entertainment'}), support=0.003332888948140248, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Classics', 'Entertainment'}), items_add=frozenset({'Comedy'}), confidence=0.48076923076923084, lift=3.4117786187322614)]), RelationRecord(items=frozenset({'Comedy', 'Travel & Events', 'Foreign'}), support=0.004666044527396347, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Comedy', 'Foreign'}), items_add=frozenset({'Travel & Events'}), confidence=0.40697674418604657, lift=3.140671356110633)]), RelationRecord(items=frozenset({'Comedy', 'Gaming', 'Horror'}), support=0.0041327822956939075, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Comedy', 'Horror'}), items_add=frozenset({'Gaming'}), confidence=0.49206349206349204, lift=5.008098037948784)]), RelationRecord(items=frozenset({'Comedy', 'Short Movies', 'News & Politics'}), support=0.0035995200639914677, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Comedy', 'News & Politics'}), items_add=frozenset({'Short Movies'}), confidence=0.46551724137931033, lift=3.523556839138453)]), RelationRecord(items=frozenset({'Drama', 'Music', 'Gaming'}), support=0.005332622317024397, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Drama', 'Music'}), items_add=frozenset({'Gaming'}), confidence=0.3225806451612903, lift=3.283144395325426)]), RelationRecord(items=frozenset({'Videoblogging', 'Movies', 'Entertainment'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Movies', 'Entertainment'}), items_add=frozenset({'Videoblogging'}), confidence=0.36507936507936506, lift=3.8300144300144296)]), RelationRecord(items=frozenset({'Family', 'Music', 'Gaming'}), support=0.004799360085321957, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Family', 'Gaming'}), items_add=frozenset({'Music'}), confidence=0.5714285 ...

# %%
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
with open('dataset.csv','w',newline='') as newsdata:
  writeit = csv.writer(newsdata)
  for i in range(0,len(transactions)):
    writeit.writerow(transactions[i])

# %%
resultsinDataFrame
# Out:
#            Left Hand Side  Right Hand Side   Support  Confidence      Lift
# 0                  Horror           Gaming  0.015998    0.323450  3.291994
# 1                  Comedy  Travel & Events  0.005333    0.416667  3.215449
# 2                 Foreign  Travel & Events  0.003600    0.402985  3.109867
# 3                  Movies            Music  0.004399    0.611111  3.509912
# 4    Science & Technology  Travel & Events  0.003200    0.393443  3.036227
# 5           Videoblogging  Travel & Events  0.004799    0.423529  3.268410
# 6        Autos & Vehicles           Gaming  0.004133    0.329787  3.356491
# 7                Classics           Comedy  0.003333    0.480769  3.411779
# 8                  Comedy  Travel & Events  0.004666    0.406977  3.140671
# 9                  Comedy           Gaming  0.004133    0.492063  5.008098
# 10                 Comedy     Short Movies  0.003600    0.465517  3.523557
# 11                  Drama           Gaming  0.005333    0.322581  3.283144
# 12                 Movies    Videoblogging  0.003066    0.365079  3.830014
# 13                 Family            Music  0.004799    0.571429  3.281995
# 14       Film & Animation           Gaming  0.006666    0.390625  3.975683
# 15       Film & Animation    Videoblogging  0.007199    0.305085  3.200616
# 16                Foreign  Travel & Events  0.003999    0.410959  3.171402
# 17                Foreign  Travel & Events  0.003066    0.442308  3.413323
# 18                Foreign  Travel & Events  0.003999    0.394737  3.046215
# 19          Videoblogging  Travel & Events  0.003999    0.500000  3.858539
# 20                  Music           Gaming  0.006399    0.393443  4.004360
# 21         Pets & Animals           Gaming  0.003200    0.461538  4.697422
# 22                 Horror           Gaming  0.003999    0.441176  4.490183
# 23        Travel & Events           Gaming  0.003600    0.391304  3.982597
# 24                 Horror           Gaming  0.015998    0.323450  3.291994
# 25   Science & Technology            Music  0.005999    0.523256  3.005315
# 26                  Music           Gaming  0.008666    0.311005  3.165328
# 27                  Music    Videoblogging  0.006666    0.318471  3.341054
# 28   Science & Technology    Videoblogging  0.003999    0.357143  3.746753
# 29  Nonprofits & Activism  Travel & Events  0.003333    0.416667  3.215449

# %%
rules1 = apriori(transactions = transactions1, min_support = 0.003, min_confidence = 0.3, min_lift = 3, min_length = 2, max_length = 3)

# %%
results2 = list(rules1)
resultsinDataFrame1 = pd.DataFrame(inspect(results2), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

#